# %% [markdown]
# ## Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests
from requests import get

# %%
book1 = requests.get("https://bookpage.com/reviews")
book1
# Out:
# <Response [200]>

# %%
book1 = BeautifulSoup(book1.content, 'html.parser')
book1
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Reviews | BookPage</title>
# <meta content="Book recommendations of the best new books by genre and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Reviews" property="og:title"/>
# <meta content="Book recommendations of the best new books by genre and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookpage" name="twitter:site"/>
# <meta content="@bookpage" name="twitter:creator"/>
# ...

# %%
#lets see how the webpage scource code downloaded above looks like

book1.content

# %%
book1.title.text
# Out:
# 'Book Reviews | BookPage'

# %%
books= book1.find_all('div',{'class':'span9'})

# %%
books
# Out:
# [<div class="span9">
#  <div class="bp-well">
#  <div class="row-fluid article-row">
#  <div class="bp-block article-info">
#  <div class="article-list-left">
#  <a href="/reviews/26241-jamie-pacton-lucky-girl-ya"><img alt="Medium" src="https://t1.bookpage.com/books/images/f05de639eed9edd68308bb5b50ba8310/medium.jpg"/></a>
#  </div>
#  <div class="flex-article-content">
#  <h4 class="italic">
#  <a href="/reviews/26241-jamie-pacton-lucky-girl-ya">Lucky Girl</a>
#  </h4>
#  <p class="sans bold">
#  Jamie Pacton
#  </p>
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=ya_fiction">YA Fiction</a>
#   /
#  <a href="/search?book_genre=ya">YA</a>
#  </p>
#  <p class="excerpt">
#  <p>Seventeen-year-old Jane Belleweather has just won $58 million in the Wisconsin lottery. It’s a life-changing amount of money that could lift Jane out of poverty and jump-start her dreams of becoming an oceanographer. Unfortunately, because Jane is a minor, she can’t come forward to...</p>
# ...

# %%
# extracting book names

# %%
titles= book1.find_all('h4',class_="italic") 
titles
# Out:
# [<h4 class="italic">
#  <a href="/reviews/26241-jamie-pacton-lucky-girl-ya">Lucky Girl</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26211-annette-gordon-reed-juneteenth-history"> <span style="font-style:normal;">★ </span>On Juneteenth</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26242-remy-lai-pawcasso-childrens">Pawcasso</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26198-chanel-cleeton-most-beautiful-girl-cuba-fiction">The Most Beautiful Girl in Cuba</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26164-sean-flynn-why-peacocks-nonfiction">Why Peacocks?</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26197-laura-dave-last-thing-he-told-me-fiction">The Last Thing He Told Me</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26215-danielle-dreilinger-secret-history-home-economics-history">The Secret History of Home Economics</a>
#  </h4>,
#  <h4 class="italic">
# ...

# %%
books_titles=[]

for i in titles:
    books_titles.append(i.text.replace('\n',''))
books_titles
# Out:
# ['Lucky Girl',
#  ' ★ On Juneteenth',
#  'Pawcasso',
#  'The Most Beautiful Girl in Cuba',
#  'Why Peacocks?',
#  'The Last Thing He Told Me',
#  'The Secret History of Home Economics',
#  'Little and Often',
#  'The Wreckage of My Presence',
#  ' ★ Secrets of Happiness']

# %%
# extracting book authors

# %%
author= book1.find_all('p',class_="sans bold") 
author
# Out:
# [<p class="sans bold">
#  Jamie Pacton
#  </p>,
#  <p class="sans bold">
#  Annette Gordon-Reed
#  </p>,
#  <p class="sans bold">
#  Remy Lai
#  </p>,
#  <p class="sans bold">
#  Chanel Cleeton
#  </p>,
#  <p class="sans bold">
#  Sean Flynn
#  </p>,
#  <p class="sans bold">
#  Laura Dave
#  </p>,
#  <p class="sans bold">
#  Danielle Dreilinger
#  </p>,
#  <p class="sans bold">
#  Trent Preszler
#  </p>,
#  <p class="sans bold">
#  Casey Wilson
#  </p>,
#  <p class="sans bold">
#  Joan Silber
#  </p>]

# %%
Authors=[]

for i in author:
    Authors.append(i.text.replace('\n',''))
Authors
# Out:
# ['Jamie Pacton',
#  'Annette Gordon-Reed',
#  'Remy Lai',
#  'Chanel Cleeton',
#  'Sean Flynn',
#  'Laura Dave',
#  'Danielle Dreilinger',
#  'Trent Preszler',
#  'Casey Wilson',
#  'Joan Silber']

# %%
#Extracting Gener

# %%
gener= book1.find_all('p',class_="genre-links hidden-phone") 
gener
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=ya_fiction">YA Fiction</a>
#   /
#  <a href="/search?book_genre=ya">YA</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=history">History</a>
#   /
#  <a href="/search?book_genre=american_history">American History</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=children_s">Children's</a>
#   /
#  <a href="/search?book_genre=middle_grade">Middle Grade</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=historical_fiction">Historical Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=science_nature">Science &amp; Nature</a>
#   /
#  <a href="/search?book_genre=animals">Animals</a>
#  </p>,
# ...

# %%
Gener=[]

for i in gener:
    Gener.append(i.text.replace('\n',''))
Gener
# Out:
# ['YA Fiction / YA',
#  'Nonfiction / History / American History',
#  "Children's / Middle Grade",
#  'Fiction / Historical Fiction',
#  'Nonfiction / Science & Nature / Animals',
#  'Fiction / Family Drama',
#  "Nonfiction / History / Women's History",
#  'Nonfiction / Memoir / Family & Relationships',
#  'Nonfiction / Essays / Humor',
#  'Fiction / Family Drama']

# %%
#extracting reviews

# %%
reviews= book1.find_all('p',class_="excerpt") 
reviews
# Out:
# [<p class="excerpt">
#  <p>Seventeen-year-old Jane Belleweather has just won $58 million in the Wisconsin lottery. It’s a life-changing amount of money that could lift Jane out of poverty and jump-start her dreams of becoming an oceanographer. Unfortunately, because Jane is a minor, she can’t come forward to...</p>
#  </p>,
#  <p class="excerpt">
#  Gordon-Reed’s essays seamlessly merge history, memoir and family history into a complex portrait of her beloved, turbulent Texas.
#  </p>,
#  <p class="excerpt">
#  <p><strong>Pawcasso</strong> is a joyful graphic novel from acclaimed author-illustrator Remy Lai (<em>Pie in the Sky</em>) that abounds with silliness, camaraderie and a few white lies.</p>
#  </p>,
#  <p class="excerpt">
#  Chanel Cleeton delivers a sweeping story of love and courage, as well as a sobering reminder of the power and responsibility of the media.
#  </p>,
#  <p class="excerpt">
# ...

# %%
Reviews=[]

for i in reviews:
    Reviews.append(i.text.replace('\n',''))
Reviews
# Out:
# ['Seventeen-year-old Jane Belleweather has just won $58 million in the Wisconsin lottery. It’s a life-changing amount of money that could lift Jane out of poverty and jump-start her dreams of becoming an oceanographer. Unfortunately, because Jane is a minor, she can’t come forward to...',
#  'Gordon-Reed’s essays seamlessly merge history, memoir and family history into a complex portrait of her beloved, turbulent Texas.',
#  'Pawcasso is a joyful graphic novel from acclaimed author-illustrator Remy Lai (Pie in the Sky) that abounds with silliness, camaraderie and a few white lies.',
#  'Chanel Cleeton delivers a sweeping story of love and courage, as well as a sobering reminder of the power and responsibility of the media.',
#  'Have you ever thought, What my household needs is a few peacocks? Me neither. But that didn’t stop me from enjoying this entertaining, sweet and often funny book.',
# ...

# %%
import pandas as pd 

BookPage=pd.DataFrame({})
BookPage['Book_titles']=books_titles[:5]
BookPage['Author']=Authors[:5]
BookPage['Gener']=Gener[:5]
BookPage['Reviews']=Reviews[:5]

# %%
BookPage
# Out:
#                        Book_titles               Author  \
# 0                       Lucky Girl         Jamie Pacton
# 1                  ★ On Juneteenth  Annette Gordon-Reed
# 2                         Pawcasso             Remy Lai
# 3  The Most Beautiful Girl in Cuba       Chanel Cleeton
# 4                    Why Peacocks?           Sean Flynn
#
#                                      Gener  \
# 0                          YA Fiction / YA
# 1  Nonfiction / History / American History
# 2                Children's / Middle Grade
# 3             Fiction / Historical Fiction
# 4  Nonfiction / Science & Nature / Animals
#
#                                              Reviews
# 0  Seventeen-year-old Jane Belleweather has just ...
# 1  Gordon-Reed’s essays seamlessly merge history,...
# 2  Pawcasso is a joyful graphic novel from acclai...
# 3  Chanel Cleeton delivers a sweeping story of lo...
# 4  Have you ever thought, What my household needs...
